# %%
class student:
    cname = 'DRIEMS'
    tollno = 12009867334
    stud_count = 0
    stud_details = {}

    def __init__(self, s_name, phone, email, address, mark1, mark2, mark3,roll_no, tot_mark, per):
        self.s_name = s_name
        self.phone = phone
        self.email = email
        self.address = address
        self.mark1 = mark1
        self.mark2 = mark2
        self.mark3 = mark3
        self.roll_no = roll_no
        self.s_name = s_name
        self.tot_mark = tot_mark
        self.per = per
        self.inc_stud_count()
        self.stud_id = 1200 + self.stud_count
        self.set_stud_details(self.stud_id, self)


    @classmethod
    def inc_stud_count(cls):
        cls.stud_count+=1

    @classmethod
    def set_stud_details(cls, id, self):
        cls.stud_details[id] = self
    
    def calculate_total_mark(self):
        return self.mark1 + self.mark2 + self.mark3
        # return
        

    @classmethod
    def display_stud_details(cls):
        s_list = cls.stud_details
        # print(s_list)
        print('Roll No','student name', 'Email', 'Phone No', 'Total mark', 'Percentage', 'Address', sep='     |     ')
        for i in s_list:
            print(s_list[i].roll_no, 
                  s_list[i].s_name, 
                  s_list[i].email,
                  s_list[i].phone,
                  s_list[i].tot_mark,
                  s_list[i].per,
                  s_list[i].address, sep='               ')

    def display_spc_stud_details(self):
        u_id = int(input("Enter Student ID: "))
        if u_id in self.stud_details:
            res=self.stud_details[u_id]
            print('Student Name: ', res.s_name)
            print('Student Phone: ', res.phone)
            print('student Email: ', res.email)
            print('student Address: ', res.address)
            print('student Mark1: ', res.mark1)
            print('student Mark2: ', res.mark2)
            print('student Mark2: ', res.mark2)
        else:
            print('Invalid Id.....Please Enter A valid ID')


    def modify_marks(self):
        n=int(input("Choose 1.mark1\n2.mark2\n3.mark3\n4.exit:"))
        match n:
            case 1:
                self.mark1 = int(input("Change The Mark1:"))
                print('Mark is success fullly changed with new mark', self.mark1)
            case 2:
                self.mark2 = int(input("Change The Mark2 :"))
                print('Mark is success fullly changed with new mark', self.mark2)
            case 3:
                self.mark3 = int(input("Change The Mark3:"))
                print('Mark is success fullly changed with new mark', self.mark3)
            case _:
                return 
        return 

    @classmethod
    def change_school_tollno(cls):
        cls.tollno = int(input("Enter A New Toll No: "))
        print('Number is successfully changed')



ashu = student('ashu', 9876543213, 'ashu@gmail.com', 'odisha', 68, 73, 95, 101, 432, '71%')
raja = student('raja', 9876543213, 'raja@gmail.com', 'banglore', 67, 87, 90, 102, 530, '88%')
ram = student('ram', 9876543213, 'ram@gmail.com', 'banglore', 67, 87, 90, 103, 468, '79%')

def main(self):
    n=int(input("choose 1.Display Student Details \n 2.Display Specific Student Details \n 3.calculate total \n 4. Modify Marks\n 5.  \n 6.Exit"))
    match n:
        case 1:
            self.display_stud_details()
        case 2:
            self.display_spc_stud_details()
        case 3:
            self.calculate_total_mark()
        case 4:
            self.modify_marks()
        case 5:
            self.change_school_tollno()
        case _:
            return
    return self.main()
main(student)
# obj = student()

# raja.calculate_total_mark()
# student.display_stud_details()
# student.stud_details[1203].__dict__
# ashu.modify_marks()
# student.change_school_tollno()

# ashu.display_spc_stud_details()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\HP\Documents\GitHub\Basic_of_python_programs\OOPS\Test_OOPs.IPYNB Cell 1 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#W0sZmlsZQ%3D%3D?line=106'>107</a>             return
#     <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#W0sZmlsZQ%3D%3D?line=107'>108</a>     return self.main()
# --> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#W0sZmlsZQ%3D%3D?line=108'>109</a> main()
#     <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#W0sZmlsZQ%3D%3D?line=109'>110</a> # obj = student()
# ...

# %%
a={1201:{'name':'hari', 'age':21, 'address':'hyd'}, 1202:{'name':'raghu', 'age':23, 'address':'Banglore'}}
for i in a:
    print(a[i].name,
          a[i].age)

print(a[1201])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\HP\Documents\GitHub\Basic_of_python_programs\OOPS\Test_OOPs.IPYNB Cell 2 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#X11sZmlsZQ%3D%3D?line=0'>1</a> a={1201:{'name':'hari', 'age':21, 'address':'hyd'}, 1202:{'name':'raghu', 'age':23, 'address':'Banglore'}}
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#X11sZmlsZQ%3D%3D?line=1'>2</a> for i in a:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#X11sZmlsZQ%3D%3D?line=2'>3</a>     print(a[i].name,
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#X11sZmlsZQ%3D%3D?line=3'>4</a>           a[i].age)
# ...

# %%
x={1201:{'a':10, 'b':20}}
res=x[1201]
print(res)
print(res.a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\HP\Documents\GitHub\Basic_of_python_programs\OOPS\Test_OOPs.IPYNB Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#X13sZmlsZQ%3D%3D?line=0'>1</a> x={1201:{a:10, 'b':20}}
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#X13sZmlsZQ%3D%3D?line=1'>2</a> res=x[1201]
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#X13sZmlsZQ%3D%3D?line=2'>3</a> print(res)
#
# TypeError: unhashable type: 'dict'

# %%
class student:
    stud_count=0
    stud_subs=3
    stud_details={}
    def _init_(self,studName,phone,email,address,mark1,mark2,mark3):
        self.stud_name = studName
        self.stud_phone = phone
        self.stud_email = email
        self.stud_address = address
        self.stud_mark1 = mark1
        self.stud_mark2 = mark2
        self.stud_mark3 = mark3
        self.inc_student_count()
        self.stud_id=100+self.stud_count

    @classmethod
    def inc_student_count(cls):
        cls.stud_count+=1

    @classmethod
    def setStudDetails(cls,stud_id,self):
        if stud_id not in self.stud_details:
            cls.stud_details[stud_id]=self

    def calculate_total(self,mark1,mark2,mark3):
         return mark1 + mark2 + mark3

    def displayStudDetails(self):
        print(" student id:",self.stud_id," Name: ",self.stud_name ,
               "Total Marks: ",self.calculate_total(self.stud_mark1,self.stud_mark2,self.stud_mark3))
        
    def Display_specific_student(self):
        studentdetails=int(input("enyer stud id to know details"))
        for id in self.stud_details.items():
            if studentdetails in self.stud_details and studentdetails==self.stud_details[id]:
                    print("Student ID : ",studentdetails)
                    print("Student Name : ",self.stud_name)
                    print("Phone Number : ",self.stud_phone)
                    print("Email Address : ",self.stud_email)
                    print("Address : ",self.stud_address)
                    print("Mark 1 : ",self.stud_mark1)
                    print("Mark 2 : ",self.stud_mark2)
                    print("Mark 3 : ",self.stud_mark3)
                    print("Total Marks : ",self.calculate_total(self.stud_mark1,self.stud_mark2,self.stud_mark3))

    def modify_marks(self, marknum):
        if marknum == 1:
            self.mark1 = int(input("enter new mark"))
        elif marknum == 2:
            self.mark2 = int(input("enter new mark"))
        elif marknum == 3:
            self.mark3 = int(input("enter new mark"))

    def change_school_phone(cls):
        cls.school_phone = int(input("enter new phone"))

syed=student("Ahamad",7794994036,"ahamad@gmail.com","hyd",80,76,92)
riyaz=student("riyaz",1122334455,"riyaz@gmail.com","hyd",65,67,84)
ghouse=student("ghouse",7791234566,"ghouse@gmail.com","hyd",88,82,95)
nabeel=student("nabeel",9988665544,"nabeel@gmail.com","hyd",83,79,91)
       
def main(cls):
    stu_id=int(input("enter student id:"))
    if stu_id in cls.stud_details:
        n=int(input("choose 1.modify marks \n 2.change  phone \n 3.calculate total \n 4.display student details \n 5. Display specific student \n 6.Exit"))
        self=cls.stud_details[stu_id]
        match n:
            case 1:
                cls.modify_marks(self)
            case 2:
                cls.change_school_phone(self)
            case 3:
                cls.calculate_total(self)
            case 4:
                cls.displayStudDetails(self)
            case 5:
                cls.Display_specific_student(self)
            case _:
                return 
    
                
                                                            



main(student)

# %%
class student:
    cname = 'DRIEMS'
    tollno = 12009867334
    stud_count = 0
    stud_details = {}

    def __init__(self, s_name, phone, email, address, mark1, mark2, mark3,roll_no, tot_mark, per):
        self.s_name = s_name
        self.phone = phone
        self.email = email
        self.address = address
        self.mark1 = mark1
        self.mark2 = mark2
        self.mark3 = mark3
        self.roll_no = roll_no
        self.s_name = s_name
        self.tot_mark = tot_mark
        self.per = per
        self.inc_stud_count()
        self.stud_id = 1200 + self.stud_count
        self.set_stud_details(self.stud_id, self)


    @classmethod
    def inc_stud_count(cls):
        cls.stud_count+=1

    @classmethod
    def set_stud_details(cls, id, self):
        cls.stud_details[id] = self
    
    def calculate_total_mark(self):
        return self.mark1 + self.mark2 + self.mark3

    @classmethod
    def display_stud_details(cls):
        s_list = cls.stud_details
        print('Roll No','student name', 'Total mark', 'Percentage',sep='  |  ')
        for i in s_list:
            print(s_list[i].roll_no, 
                  s_list[i].s_name, 
                  s_list[i].tot_mark,
                  s_list[i].per, sep='            ')

    def display_spc_stud_details(self):
        u_id = int(input("Enter Student ID: "))
        if u_id in self.stud_details:
            res=self.stud_details[u_id]
            print('Student Name: ', res.s_name)
            print('Student Phone: ', res.phone)
            print('student Email: ', res.email)
            print('student Address: ', res.address)
            print('student Mark1: ', res.mark1)
            print('student Mark2: ', res.mark2)
            print('student Mark2: ', res.mark2)
        else:
            print('Invalid Id.....Please Enter A valid ID')



    def modify_marks(self):
        n=int(input("Choose 1.mark1\n2.mark2\n3.mark3\n4.exit:"))
        match n:
            case 1:
                self.mark1 = int(input("Change The Mark1:"))
                print('Mark is success fullly changed with new mark', self.mark1)
            case 2:
                self.mark2 = int(input("Change The Mark2 :"))
                print('Mark is success fullly changed with new mark', self.mark2)
            case 3:
                self.mark3 = int(input("Change The Mark3:"))
                print('Mark is success fullly changed with new mark', self.mark3)
            case _:
                return 
        return 

    @classmethod
    def change_school_tollno(cls):
        cls.tollno = int(input("Enter A New Toll No: "))
        print('Number is successfully changed')



@classmethod
def main(cls,self):
    # s_id=int(input("Enter Student id:"))
    # if s_id in cls.stud_details:
    n=int(input("choose 1.Display Student Details \n 2.Display Specific Student Details \n 3.calculate total \n 4. Modify Marks\n 5.  \n 6.Exit"))
    # self=cls.stud_details[s_id]
    match n:
        case 1:
            self.display_stud_details()
        case 2:
            self.display_spc_stud_details(self)
        case 3:
            self.calculate_total_mark(self)
        case 4:
            self.modify_marks()
        case 5:
            self.change_school_tollno()
        case _:
            return
    return self.main()
ashu = student('ashu', 9876543213, 'ashu@gmail.com', 'odisha', 68, 73, 95, 101, 432, '71%')
raja = student('raja', 9876543213, 'raja@gmail.com', 'banglore', 67, 87, 90, 102, 530, '88%')
ram = student('ram', 9876543213, 'ram@gmail.com', 'banglore', 67, 87, 90, 103, 468, '79%')

def home(cls):
    n=int(input("enter the id"))
    if n in cls.stud_details:
        cls.main(self)
home(student)
# obj = student()

# raja.calculate_total_mark()
# student.display_stud_details()
# student.stud_details[1203].__dict__
# ashu.modify_marks()
# student.change_school_tollno()

# ashu.display_spc_stud_details()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\HP\Documents\GitHub\Basic_of_python_programs\OOPS\Test_OOPs.IPYNB Cell 2 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#W5sZmlsZQ%3D%3D?line=109'>110</a>     if n in cls.stud_details:
#     <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#W5sZmlsZQ%3D%3D?line=110'>111</a>         cls.main(self)
# --> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#W5sZmlsZQ%3D%3D?line=111'>112</a> home(student)
#     <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/Test_OOPs.IPYNB#W5sZmlsZQ%3D%3D?line=112'>113</a> # obj = student()
# ...

# %%
i = 1
while True:
    if i%3 == 0:
        break
    print(i)
 
    i + = 1
# Out:
#   Cell In[138], line 7
#     i + = 1
#         ^
# SyntaxError: invalid syntax

# %%
i = 0
while i < 5:
    print(i)
    i += 1
    if i == 3:
        break
else:
    print(0)
# Out:
# 0
# 1
# 2

# %%
print([[i+j for i in "abc"] for j in "def"])
# Out:
# [['ad', 'bd', 'cd'], ['ae', 'be', 'ce'], ['af', 'bf', 'cf']]

# %%
i = 0
while i < 3:
       print(i)
       i += 1 
else:
      print(0)
# Out:
# 0
# 1
# 2
# 0
