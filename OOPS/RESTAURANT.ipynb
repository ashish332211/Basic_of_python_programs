# %%
class restaurant:
    rname = 'SUN SHINE'
    rid = 1234567
    address = 'Odisha'
    phone = 9876543213
    cart={}

    def __init__(self):
        self.menu = {'paneer masala':160,
        'paneer tikka':180,
        'paneer kadai':200,
        'mashroom masala':160,
        'mashroom chilli':180}

    def nonvej_item(self):
        print('NONVEJ ITEMS'," "*10, 'PRICE')
        print('-'*30)
        print('Chicken handi',' '*10, 180)
        print('Chicken masala',' '*9, 180)
        print('Chicken khurma',' '*9, 180)
        print('Mutton masala',' '*10, 240)
        print('Mutton curry',' '*11, 240)
        print('*'*30)


    def nonvej_starter(self):
        print('NONVEJ STARTER'," "*9, 'PRICE')
        print("-"*30)
        print('Chicken pakoda',' '*10, 120)
        print('Chicken 65',' '*14, 140)
        print('Chicken 90',' '*14, 190)
        print('Chicken Manchurian',' '*6, 140)
        print("*"*20)


    def vej_item(self):
        print('VEJ ITEMS', " "*10, 'PRICE')
        print("-"*20)
        print('paneer masala',' '*6, 160)
        print('paneer tikka',' '*7,180)
        print('paneer kadai',' '*7,200)
        print('mashroom masala',' '*4,160)
        print('mashroom chilli',' '*4,180)
        print("*"*20)


    def vej_starter(self):
        print('VEG STARTER', " "*10, 'PRICE')
        print('-'*20)
        print('kobi manchurian',' '*6,120)
        print('kobi pakoda',' '*11,100)
        print('paneer 90',' '*11,130)
        print('paneer pakoda',' '*8,120)
        print('paneer kuft kuft',' '*5,120)
        print("*"*20)



    def display(self):
        res=0
        odr={}
        odr1={}
        while True:
            opt=int(input("Choose Option\n1.Choose Items:\n2.Cart\n3.Confirm\n4.bill\n5.Exit"))
            if opt==1:
                n = input("Enter Item: ")
                if n in self.menu:
                    res+=self.menu[n]
                    odr1.update({n:self.menu[n]})
                    if n not in odr:
                        odr[n]=1
                    else:
                        odr[n]+=1
                else:
                    print("Sorry...Your Found Item Is Not Available")
            elif opt==2:
                print('The selected items are:', odr1)
            elif opt==3:
                print('Quantity of the items:', odr)
            elif opt==4:
                print('Your Total Amount Is:', res)
            elif opt==5:
                break

# obj=restaurant()
# obj.nonvej_item()
# obj.nonvej_starter()
# obj.vej_item()
# obj.vej_starter()

# obj.display()
# print(res.__dict__)

# %%
class payment:
    def __init__(self,upi,pin):
        self.upi=upi
        self.pin=pin
        self.c_pin=9078
        self.c_upi='123@gpay'
    
    def valid(self):
        if self.c_pin==self.pin and self.c_upi==self.upi:
            print('Payment Successful')
            print('Your Order is Placed')
        else:
            print('Wrong UPI or PIN...Please Enter Correct UPI or PIN')

# %%
class restaurant:
    def __init__(self,un,pw):
        self.username='ashu'
        self.password=1234
        self.un=un
        self.pw=pw
    
    def validation(self):
        if self.un==self.username and self.pw==self.password:
            print('You Are A Valid User')
            obj=restaurant(un,pw)
            while True:
                option=int(input("Enter Choice\n1.Nonvej_Items\n2.Nonvej_Starter\n3.Vej_Items\n4.Vej_Starter\n5.Display\n6.Payment\n7.Exit"))
                print('*'*50)
                if option==1:
                    obj.nonvej_item()
                elif option==2:
                    obj.nonvej_starter()
                elif option==3:
                    obj.vej_item()
                elif option==4:
                    obj.vej_starter()
                elif option==5:
                    obj.display()
                elif option==6:
                    upi=input("Enter UPI NO.")
                    pin=int(input("Enter PIN:"))
                    obj1=payment(upi,pin)
                    obj1.valid()
                elif option==7:
                    print('-----THANKS FOR VISITING-----')
                    break
                else:
                    print('Invalid Option')
un=input("Enter Username")
pw=int(input("Enter Password"))
obj=restaurant(un,pw)
obj.validation()
# Out:
# You Are A Valid User
# **************************************************
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\HP\Documents\GitHub\Basic_of_python_programs\OOPS\RESTAURANT.ipynb Cell 3 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/RESTAURANT.ipynb#W2sZmlsZQ%3D%3D?line=35'>36</a> pw=int(input("Enter Password"))
#      <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/RESTAURANT.ipynb#W2sZmlsZQ%3D%3D?line=36'>37</a> obj=restaurant(un,pw)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/GitHub/Basic_of_python_programs/OOPS/RESTAURANT.ipynb#W2sZmlsZQ%3D%3D?line=37'>38</a> obj.validation()
#
# c:\Users\HP\Documents\GitHub\Basic_of_python_programs\OOPS\RESTAURANT.ipynb Cell 3 line 2
# ...
